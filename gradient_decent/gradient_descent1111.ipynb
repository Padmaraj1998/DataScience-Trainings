# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
def gradient_descent(x,y):
    m_curr = 0
    b_curr = 0
    learning_rate = 0.001
    n_iteration = 10000
    n = len(x)
    
    fig, ax = plt.subplots()
    ax.scatter(x, y, label='Data Points')
    
    for i in range(n_iteration):
        y_pred = m_curr*x+b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_pred)])
        md = -(2/n) * sum(x*(y-y_pred))
        bd = -(2/n) * sum(y-y_pred)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        #print("slope =",m_curr,"intercept =",b_curr,"error =",cost,"iteration = ",i)
        
        
        ax.clear()
        ax.scatter(x, y, label='Data Points')
        ax.plot(x, y_pred, color='red', label='Regression Line')
        ax.set_title(f'Iteration: {i+1}, Cost: {cost:.2f}')
        ax.legend()

# %%
gradient_descent(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Generate some random data for demonstration
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Initialize weights and bias
w = np.random.randn(1, 1)
b = np.random.randn(1, 1)

# Learning rate
alpha = 0.01

# Number of iterations
iterations = 100

# Create a figure and axis
fig, ax = plt.subplots()
ax.scatter(X, y, label='Data Points')

# Function to update the plot in each iteration
def update_plot(i):
    global w, b
    
    # Forward pass
    y_pred = np.dot(X, w) + b
    
    # Compute the cost (Mean Squared Error)
    cost = np.mean((y_pred - y)**2)
    
    # Backward pass (Gradient Descent)
    dw = np.mean((y_pred - y) * X)
    db = np.mean(y_pred - y)
    
    # Update weights and bias
    w -= alpha * dw
    b -= alpha * db
    
    # Plot the regression line
    ax.clear()
    ax.scatter(X, y, label='Data Points')
    ax.plot(X, y_pred, color='red', label='Regression Line')
    ax.set_title(f'Iteration: {i+1}, Cost: {cost:.2f}')
    ax.legend()

# Create the animation
animation = FuncAnimation(fig, update_plot, frames=iterations, interval=200)

# Display the animation
plt.show()

# %%
animation = FuncAnimation(fig, update_plot, frames=iterations, interval=200)
plt.show()
